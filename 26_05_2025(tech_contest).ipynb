# %% [markdown]
# <a href="https://colab.research.google.com/github/Him99224/2023410641_CSL/blob/main/26_05_2025(tech_contest).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/Diwali Sales Data.csv',encoding='ISO-8859-1')

# %%
df.to_csv('Diwali Sales Data_UTF-8.csv')

# %%
df=pd.read_csv('/content/Diwali Sales Data_UTF-8.csv')

# %%
df
# Out:
#        Unnamed: 0  User_ID    Cust_name Product_ID Gender Age Group  Age  \
# 0               0  1002903    Sanskriti  P00125942      F     26-35   28
# 1               1  1000732       Kartik  P00110942      F     26-35   35
# 2               2  1001990        Bindu  P00118542      F     26-35   35
# 3               3  1001425       Sudevi  P00237842      M      0-17   16
# 4               4  1000588         Joni  P00057942      M     26-35   28
# ...           ...      ...          ...        ...    ...       ...  ...
# 11246       11246  1000695      Manning  P00296942      M     18-25   19
# 11247       11247  1004089  Reichenbach  P00171342      M     26-35   33
# 11248       11248  1001209        Oshin  P00201342      F     36-45   40
# 11249       11249  1004023       Noonan  P00059442      M     36-45   37
# 11250       11250  1002744      Brumley  P00281742      F     18-25   19
#
#        Marital_Status           State      Zone       Occupation  \
# ...

# %%
df.shape
# Out:
# (11251, 16)

# %%
df.head()
# Out:
#    Unnamed: 0  User_ID  Cust_name Product_ID Gender Age Group  Age  \
# 0           0  1002903  Sanskriti  P00125942      F     26-35   28
# 1           1  1000732     Kartik  P00110942      F     26-35   35
# 2           2  1001990      Bindu  P00118542      F     26-35   35
# 3           3  1001425     Sudevi  P00237842      M      0-17   16
# 4           4  1000588       Joni  P00057942      M     26-35   28
#
#    Marital_Status           State      Zone       Occupation Product_Category  \
# 0               0     Maharashtra   Western       Healthcare             Auto
# 1               1  Andhra Pradesh  Southern             Govt             Auto
# 2               1   Uttar Pradesh   Central       Automobile             Auto
# 3               0       Karnataka  Southern     Construction             Auto
# 4               1         Gujarat   Western  Food Processing             Auto
#
#    Orders   Amount  Status  unnamed1
# 0       1  23952.0     NaN       NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        11251 non-null  int64
#  1   User_ID           11251 non-null  int64
#  2   Cust_name         11251 non-null  object
#  3   Product_ID        11251 non-null  object
#  4   Gender            11251 non-null  object
#  5   Age Group         11251 non-null  object
#  6   Age               11251 non-null  int64
#  7   Marital_Status    11251 non-null  int64
#  8   State             11251 non-null  object
#  9   Zone              11251 non-null  object
#  10  Occupation        11251 non-null  object
#  11  Product_Category  11251 non-null  object
#  12  Orders            11251 non-null  int64
#  13  Amount            11239 non-null  float64
#  14  Status            0 non-null      float64
#  15  unnamed1          0 non-null      float64
# ...

# %%
df.drop(['Status','unnamed1'],axis=1,inplace=True)

# %%
df
# Out:
#        Unnamed: 0  User_ID    Cust_name Product_ID Gender Age Group  Age  \
# 0               0  1002903    Sanskriti  P00125942      F     26-35   28
# 1               1  1000732       Kartik  P00110942      F     26-35   35
# 2               2  1001990        Bindu  P00118542      F     26-35   35
# 3               3  1001425       Sudevi  P00237842      M      0-17   16
# 4               4  1000588         Joni  P00057942      M     26-35   28
# ...           ...      ...          ...        ...    ...       ...  ...
# 11246       11246  1000695      Manning  P00296942      M     18-25   19
# 11247       11247  1004089  Reichenbach  P00171342      M     26-35   33
# 11248       11248  1001209        Oshin  P00201342      F     36-45   40
# 11249       11249  1004023       Noonan  P00059442      M     36-45   37
# 11250       11250  1002744      Brumley  P00281742      F     18-25   19
#
#        Marital_Status           State      Zone       Occupation  \
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0           0
# User_ID              0
# Cust_name            0
# Product_ID           0
# Gender               0
# Age Group            0
# Age                  0
# Marital_Status       0
# State                0
# Zone                 0
# Occupation           0
# Product_Category     0
# Orders               0
# Amount              12
# dtype: int64

# %%
mean_age=df['Age'].mean()
mean_orders=df['Orders'].mean()
mean_amount=df['Amount'].mean()
print(mean_age,mean_orders,mean_amount)
# Out:
# 35.421207003821884 2.4892898409030306 9453.610857727557

# %%
df.describe()
# Out:
#          Unnamed: 0       User_ID           Age  Marital_Status        Orders  \
# count  11251.000000  1.125100e+04  11251.000000    11251.000000  11251.000000
# mean    5625.000000  1.003004e+06     35.421207        0.420318      2.489290
# std     3248.028274  1.716125e+03     12.754122        0.493632      1.115047
# min        0.000000  1.000001e+06     12.000000        0.000000      1.000000
# 25%     2812.500000  1.001492e+06     27.000000        0.000000      1.500000
# 50%     5625.000000  1.003065e+06     33.000000        0.000000      2.000000
# 75%     8437.500000  1.004430e+06     43.000000        1.000000      3.000000
# max    11250.000000  1.006040e+06     92.000000        1.000000      4.000000
#
#              Amount
# count  11239.000000
# mean    9453.610858
# std     5222.355869
# min      188.000000
# 25%     5443.000000
# 50%     8109.000000
# 75%    12675.000000
# max    23952.000000

# %%
plt.figure(figsize=(10,10))
sns.countplot(x='Gender',hue='Gender',data=df)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
plt.figure(figsize=(10,10))
sns.barplot(x='Gender',y='Amount',hue='Gender',data=df)
# Out:
# <Axes: xlabel='Gender', ylabel='Amount'>

# %%
sns.countplot(x='Age Group',hue='Gender',data=df)
# Out:
# <Axes: xlabel='Age Group', ylabel='count'>

# %%
df.groupby(['State','Amount'],as_index=False)['Amount'].sum().sort_values(by='Amount',ascending=False).head(10)
# Out:
#                State   Amount
# 2109           Delhi  60936.0
# 7813     Maharashtra  57960.0
# 7807     Maharashtra  57753.0
# 10155  Uttar Pradesh  47136.0
# 7638     Maharashtra  46548.0
# 9717   Uttar Pradesh  45702.0
# 5201       Karnataka  41824.0
# 5194       Karnataka  41630.0
# 5191       Karnataka  41534.0
# 2148           Delhi  41504.0

# %%
import matplotlib.pyplot as plt
orders_state=df.groupby(['State'],as_index=False)['Orders'].sum().sort_values(by='Orders',ascending=False).head(10)
plt.figure(figsize=(15, 5))
sns.barplot(x='State',y='Orders',hue='State',data=orders_state)
# Out:
# <Axes: xlabel='State', ylabel='Orders'>

# %%
sales_state = df.groupby(['State'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False).head(10)

plt.figure(figsize=(20, 5))
sns.barplot(x='State', y='Amount',hue='State', data=sales_state)
plt.title('Total Sales by Top 10 States')
plt.xlabel('State')
plt.ylabel('Total Amount (Sales)')
plt.show()

# %%
sns.countplot(x='Marital_Status',data=df)
# Out:
# <Axes: xlabel='Marital_Status', ylabel='count'>

# %%
top_occupation=df.groupby(['Occupation'],as_index=False)['Amount'].sum().sort_values(by='Amount',ascending=False).head(10)
plt.figure(figsize=(15, 5))
sns.barplot(x='Occupation',y='Amount',hue='Occupation',data=top_occupation)
# Out:
# <Axes: xlabel='Occupation', ylabel='Amount'>

# %%
category_counts = df['Product_Category'].value_counts().head(10)
plt.figure(figsize=(15, 7))
sns.countplot(y='Product_Category', data=df, order=category_counts.index)
plt.title('Top 10 Product Categories')
plt.xlabel('Count')
plt.ylabel('Product Category')
plt.show()
